# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
from numpy import nan
import statistics as stat
import math

# %%
path = '/Users/paw_paw/Library/CloudStorage/GoogleDrive-keyuqing597@gmail.com/我的云端硬盘/PC5287_M.SC Coursework Thesis for Physics And Technology/data set'
Prediction = pd.read_csv(path+'/Prediction_i2j_use_Residents.csv').drop(columns='Unnamed: 0').drop(columns='PA_name')
T_ij_bus= pd.read_csv(path+'/Total_bus_flux_ij2019.csv').drop(columns='Unnamed: 0')
T_ij_MRT = pd.read_csv(path + '/Total_MRT_flux_ij2019.csv').drop(columns='Unnamed: 0')

# %%
Prediction
# Out:
#       BUKIT MERAH  BUKIT PANJANG    BUKIT TIMAH  CENTRAL WATER CATCHMENT  \
# 0             NaN   4.929567e+04    6252.345789                      NaN
# 1    13338.646369            NaN    2647.261864                      NaN
# 2    28788.431090   2.575930e+05            NaN                      NaN
# 3        0.000000   0.000000e+00       0.000000                      NaN
# 4       74.742510   4.739624e+01      31.405551                      0.0
# 5    26374.956313   8.096587e+05   80422.546377                      0.0
# 6    43768.316473   1.934123e+05  371779.100777                      0.0
# 7    34465.823637   2.932948e+04   20294.204714                      0.0
# 8    28808.521767   6.244168e+04   50856.851269                      0.0
# 9   190731.730101   5.430481e+05  223743.310997                      0.0
# 10   59686.808245   8.988707e+03   13055.757548                      0.0
# 11       0.030557   4.474459e-01       0.070634                      0.0
# 12       4.205123   5.782593e+01      10.252792                      0.0
# 13       0.000000   0.000000e+00       0.000000                      0.0
# 14   18708.013468   9.158583e+03   24490.483505                      0.0
# 15   11925.269377   9.739231e+03    6230.279840                      0.0
# 16       0.000000   0.000000e+00       0.000000                      0.0
# 17    7785.338130   9.095863e+03    5226.712895                      0.0
# 18   17855.790812   7.289445e+04   36664.699722                      0.0
# 19   90583.499153   4.996633e+04   37412.144899                      0.0
# 20   11558.502990   2.713403e+04   30712.504186                      0.0
# 21       0.000000   0.000000e+00       0.000000                      0.0
# 22   30262.019414   2.471909e+06  130540.976195                      0.0
# 23  899846.123242   1.231916e+05  326564.693220                      0.0
# 24       0.544895   8.339900e-01       0.436513                      0.0
# 25    3247.635503   2.595340e+04    5621.826831                      0.0
# 26   19691.231463   2.383765e+04   14496.083062                      0.0
# 27   10475.133791   1.258540e+04    9257.440747                      0.0
# 28       0.000000   0.000000e+00       0.000000                      0.0
# 29    4968.277654   1.382427e+00       4.383553                      0.0
# 30      14.528564   3.244841e+02      40.730459                      0.0
# 31   76316.820636   4.713038e+04   29843.661035                      0.0
# 32   19048.015806   1.839049e+03   12505.272374                      0.0
# 33       0.000000   0.000000e+00       0.000000                      0.0
# 34   41743.574290   1.851903e+04   24877.550238                      0.0
# 35       0.000000   0.000000e+00       0.000000                      0.0
# 36   21073.085305   2.876115e+02     597.097215                      0.0
# 37       0.000000   0.000000e+00       0.000000                      0.0
# 38       0.000000   0.000000e+00       0.000000                      0.0
# 23  130276.782453  ...              NaN           NaN         NaN
# 24       0.786505  ...              NaN           NaN         NaN
# 25    8521.118830  ...              NaN           NaN         NaN
# 26   23337.553616  ...              NaN           NaN         NaN
# 27   10458.812551  ...              NaN           NaN         NaN
# 28       0.000000  ...              NaN           NaN         NaN
# 29       1.181663  ...              NaN           NaN         NaN
# 30     127.803547  ...              NaN           NaN         NaN
# 31   46352.947330  ...              NaN           NaN         NaN
# 32     703.559759  ...     1.351613e+06           NaN         NaN
# 33       0.000000  ...              NaN           NaN         NaN
# 34   14526.787429  ...     1.704924e+06           NaN         NaN
# 35       0.000000  ...              NaN           NaN         NaN
# 36     204.605736  ...     7.056552e+05           NaN         NaN
# 37       0.000000  ...              NaN           NaN         NaN
# 38       0.000000  ...              NaN           NaN         NaN
# 39       1.560471  ...     1.632038e+00           NaN         NaN
# 40     323.981709  ...     3.489721e+04           NaN         NaN
# 41      57.780073  ...     3.616090e+06           NaN         NaN
# 42    1068.023853  ...     9.411631e+00           NaN         NaN
# 43      20.962618  ...     1.808360e-01           NaN         NaN
# 44     883.161817  ...     1.267464e+04           NaN         NaN
# 45      45.628358  ...              NaN           NaN         NaN
# 46       0.000000  ...     0.000000e+00           NaN         NaN
# 47       0.000000  ...     0.000000e+00           0.0         NaN
# 48     925.122945  ...     5.048156e+02           0.0         0.0
# 49   15208.223731  ...     2.004804e+03           0.0         0.0
# 50       0.000000  ...     0.000000e+00           0.0         0.0
# 51       0.000000  ...     0.000000e+00           0.0         0.0
# 52    2145.401711  ...     1.800333e-01           0.0         0.0
# 53  144739.982267  ...     8.799773e+02           0.0         0.0
# 54   32724.002931  ...     6.562157e+02           0.0         0.0
#
#     MARINE PARADE        GEYLANG  PAYA LEBAR  WESTERN ISLANDS  \
# 0    1.645977e+05    8820.635604         NaN              NaN
# 1    7.269414e+07    5521.419531         NaN              NaN
# 2             NaN    5868.336252         NaN              NaN
# 3             NaN            NaN         NaN              NaN
# 4             NaN            NaN         NaN              NaN
# 5    1.002688e+07   30110.802247         NaN              NaN
# 6    3.842928e+06   22809.463042         NaN              NaN
# 7    2.070832e+04   11577.848851         NaN              NaN
# 8             NaN   73756.474440         NaN              NaN
# 9    1.039722e+07  141819.178436         NaN              NaN
# 10   1.256020e+03    2942.283653         NaN              NaN
# 11            NaN            NaN         NaN              NaN
# 12            NaN            NaN         NaN              NaN
# 13            NaN            NaN         NaN              NaN
# 14   5.106935e+05     955.027682         NaN              NaN
# 15   1.268393e+06    4974.413187         NaN              NaN
# 16            NaN            NaN         NaN              NaN
# 17   3.147997e+06    3737.765413         NaN              NaN
# 18   3.801629e+06    9014.349641         NaN              NaN
# 19   8.613602e+03   20177.754795         NaN              NaN
# 20   7.089615e+05    2649.904895         NaN              NaN
# 21            NaN            NaN         NaN              NaN
# 22   2.279774e+07   12205.597298         NaN              NaN
# 23   1.474177e+08   25961.555140         NaN              NaN
# 24            NaN            NaN         NaN              NaN
# 25            NaN   97709.587272         NaN              NaN
# 26   2.013536e+05    9457.913706         NaN              NaN
# 27   1.474470e+05    4238.599650         NaN              NaN
# 28            NaN            NaN         NaN              NaN
# 29            NaN            NaN         NaN              NaN
# 30            NaN            NaN         NaN              NaN
# 31   9.186792e+03   18784.614095         NaN              NaN
# 32            NaN    2902.219931         NaN              NaN
# 33            NaN            NaN         NaN              NaN
# 34   7.975600e+03    5887.006363         NaN              NaN
# 35            NaN            NaN         NaN              NaN
# 36   9.786021e+04   29194.637020         NaN              NaN
# 37            NaN            NaN         NaN              NaN
# 38            NaN            NaN         NaN              NaN
# 39            NaN  188594.236683         NaN              NaN
# 40   3.155026e+06     968.896776         NaN              NaN
# 41            NaN  607240.048211         NaN              NaN
# 42   6.541166e+04    2481.569954         NaN              NaN
# 43   1.036228e+05     143.700094         NaN              NaN
# 44   3.924783e+04     343.487502         NaN              NaN
# 45   7.474070e+05   13154.653562         NaN              NaN
# 46            NaN            NaN         NaN              NaN
# 47            NaN            NaN         NaN              NaN
# 48            NaN     371.058661         NaN              NaN
# 49   5.424256e+04            NaN         NaN              NaN
# 50   0.000000e+00       0.000000         NaN              NaN
# 51   0.000000e+00       0.000000         0.0              NaN
# 52   1.215938e+00       3.623588         0.0              0.0
# 53   8.353343e+03   32944.492065         0.0              0.0
# 54   5.853602e+03   36269.964486         0.0              0.0
#
#     WESTERN WATER CATCHMENT     WOODLANDS        YISHUN
# 0                       NaN  1.966597e+04  1.718505e+04
# 1                       NaN  8.326630e+03  7.268154e+03
# 2                       NaN  4.209574e+03  3.674456e+03
# 3                       NaN           NaN           NaN
# 4                       NaN           NaN           NaN
# 5              1.557552e+06  1.778169e+04  1.552130e+04
# 6                       NaN  6.901225e+03  7.311409e+03
# 7                       NaN  2.581329e+04  2.253192e+04
# 8                       NaN  4.680441e+03  4.081943e+04
# 9              2.871755e+04  4.383746e+04  3.826487e+04
# 10                      NaN  6.559942e+03  5.726047e+03
# 11                      NaN           NaN           NaN
# 12                      NaN  5.007585e+00  4.371024e+00
# 13                      NaN           NaN           NaN
# 14                      NaN  2.129273e+03  1.858602e+03
# 15                      NaN  9.691185e+03  8.459249e+03
# 16                      NaN           NaN           NaN
# 17                      NaN  8.333501e+03  7.274152e+03
# 18                      NaN  2.009786e+04  1.754304e+04
# 19                      NaN  4.498713e+04  3.926840e+04
# 20                      NaN  5.908071e+03  5.157042e+03
# 21                      NaN           NaN           NaN
# 22             3.483893e+06  1.359413e+04  1.186606e+04
# 23                      NaN  1.067542e+04  4.766309e+04
# 24                      NaN           NaN  4.337739e+01
# 25                      NaN  5.120122e+03  4.469256e+03
# 26                      NaN  2.108681e+04  1.840627e+04
# 27                      NaN  9.450131e+03  8.248838e+03
# 28                      NaN           NaN           NaN
# 29                      NaN           NaN           NaN
# 30                      NaN  2.074918e+01           NaN
# 31                      NaN  4.188107e+04  3.655718e+04
# 32                      NaN  2.697993e+03  4.360068e+03
# 33                      NaN           NaN           NaN
# 34                      NaN  1.312532e+04  1.145684e+04
# 35                      NaN           NaN           NaN
# 36                      NaN           NaN           NaN
# 37                      NaN           NaN           NaN
# 38                      NaN           NaN           NaN
# 39                      NaN           NaN           NaN
# 40                      NaN  5.151097e+04  4.874617e+04
# 41                      NaN  6.663457e+06  6.661720e+06
# 42                      NaN  5.084137e+04  1.727043e+05
# 43                      NaN  1.848246e+03  2.757786e+03
# 44                      NaN  4.039159e+04  4.520104e+04
# 45                      NaN  1.444200e+05  1.665398e+05
# 46                      NaN           NaN           NaN
# 47                      NaN           NaN           NaN
# 48                      NaN  2.572530e+04  1.390437e+05
# 49                      NaN  1.374102e+04  1.199427e+04
# 50                      NaN           NaN           NaN
# 51                      NaN           NaN           NaN
# 52                      NaN  4.717749e+05           NaN
# 53             7.032209e+02           NaN  3.804943e+04
# 54             8.966245e+01  5.233380e+05           NaN
#
# [55 rows x 55 columns]

# %%
new_df = Prediction.copy()
for pla in Prediction.columns[0:]:
    H = stat.loc[stat['PLA']==pla,'mean'].to_numpy()[0]+3*stat.loc[stat['PLA']==pla,'std_dvt'].to_numpy()[0]
    L = stat.loc[stat['PLA']==pla,'mean'].to_numpy()[0]-3*stat.loc[stat['PLA']==pla,'std_dvt'].to_numpy()[0]
    cleanedList = [x for x in Prediction[pla].to_numpy() if np.isnan(x) == False]
    olr = [x for x in cleanedList if( x > H or x < L )]
    print(olr)
    new_df[pla] = new_df[pla].mask(new_df[pla].to_numpy()>H,H)
    new_df[pla] = new_df[pla].mask(new_df[pla].to_numpy()<L,L)
    print(new_df[pla],'/n',Prediction[pla])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 3
#       1 new_df = Prediction.copy()
#       2 for pla in Prediction.columns[0:]:
# ----> 3     H = stat.loc[stat['PLA']==pla,'mean'].to_numpy()[0]+3*stat.loc[stat['PLA']==pla,'std_dvt'].to_numpy()[0]
#       4     L = stat.loc[stat['PLA']==pla,'mean'].to_numpy()[0]-3*stat.loc[stat['PLA']==pla,'std_dvt'].to_numpy()[0]
#       5     cleanedList = [x for x in Prediction[pla].to_numpy() if np.isnan(x) == False]
#
# AttributeError: module 'statistics' has no attribute 'loc'

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection="3d")

x = np.arange(0,55,1)
y = np.arange(0,55,1)

X, Y = np.meshgrid(x, y)

Z1 = Prediction.to_numpy()
Z2 = new_df.to_numpy()

'''ax.plot_wireframe(X, Y, Z1, color='blue')'''
ax.plot_wireframe(X, Y, Z2, color='red')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Capped Prediction')

ax.set_zlim(0,1.5*10**6)

plt.show()

# %%
new = np.empty([55,55])

def bus_flux(x,y):
    pa1 = Prediction['PA_name'][x]
    pa2 = Prediction['PA_name'][y]
    
    if T_ij_bus[(T_ij_bus['ORIGIN_loc']==pa1)&(T_ij_bus['DESTINATION_loc']==pa2)].size==0:
        return int(0)
    else:
        flux = T_ij_bus[(T_ij_bus['ORIGIN_loc']==pa1)&(T_ij_bus['DESTINATION_loc']==pa2)]['TOTAL_TRIPS'].values[0]
        return flux

for i in range(0,55):
    for j in range(0,55):
        new[i][j]=bus_flux(i,j)
        new[i][i]=0

bus_flux_array = new

new = np.empty([55,55])
def MRT_flux(x,y):
    pa1 = Prediction['PA_name'][x]
    pa2 = Prediction['PA_name'][y]
    
    if T_ij_MRT[(T_ij_MRT['ORIGIN_loc']==pa1)&(T_ij_MRT['DESTINATION_loc']==pa2)].size==0:
        return int(0)
    else:
        flux = T_ij_MRT[(T_ij_MRT['ORIGIN_loc']==pa1)&(T_ij_MRT['DESTINATION_loc']==pa2)]['TOTAL_TRIPS'].values[0]
        return flux
for i in range(0,55):
    for j in range(0,55):
        new[i][j]=MRT_flux(i,j)
MRT_flux_array = new

flux_array=(bus_flux_array+MRT_flux_array)

flux = pd.DataFrame(flux_array)

# %%
flux

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

fx= np.arange(0,55,1)
fy = np.arange(0,55,1)

X, Y = np.meshgrid(fx, fy)

Z = flux_array

ax.plot_wireframe(X, Y, Z, color='green')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('T_ij')

plt.show()

# %%
stat = Prediction.copy()

'''stat = stat - flux'''

print(stat.dtypes,flux.dtypes)

# %%
abs_error = pd.DataFrame((stat.to_numpy()-flux.to_numpy()))

abs_error

# %%
try:
    x = stat.to_numpy()-flux.to_numpy()
    y = flux.to_numpy()
    rlt_error = abs(2*np.arctan(x/y)-np.pi/2)
except RuntimeWarning:
    rlt_error = abs(2*np.arctan(np.inf)-np.pi/2)

# %%
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection="3d")

fx= np.arange(0,55,1)
fy = np.arange(0,55,1)

X, Y = np.meshgrid(fx, fy)

Z = abs_error.to_numpy()

ax = plt.axes(projection="3d")
ax.plot_wireframe(X, Y, Z, color='green')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('abs_error')
ax.set_zlim(-10**6,2.5*10**6)
ax.set_title('T_ij')

plt.show()

# %%
new_stat = pd.DataFrame()
new_stat['PLA'] = Prediction.columns

for i in range(0,55):
    cleanedList = [x for x in Prediction.to_numpy()[i] if np.isnan(x) == False]
    new_stat.loc[i,'mean'] = statistics.mean(cleanedList)
    new_stat.loc[i,'std_dvt'] = np.std(cleanedList)

new_stat

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes()

x = np.arange(0,55,1)
y = new_stat['std_dvt']/new_stat['mean']

ax.plot(x,y, color='blue')
ax.set_xlabel('x',fontdict={'family' : 'Times New Roman', 'size':26})
ax.set_ylabel('std/mean',fontdict={'family' : 'Times New Roman', 'size':26})
plt.yticks(fontproperties = 'Times New Roman', size = 22)

plt.show()
